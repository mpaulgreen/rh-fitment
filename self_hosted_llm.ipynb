# %% [markdown]
# ## model - DeepSeek-R1-Distill-Qwen-14B-W4A16 model
# #### Analysis performed to gain insights into CVE data. This model was chosen as enterprise OpenAI account was not readily available.
# #### About 4.6% was found to be code related

# %%
import os
import time
import json
import requests
import re
import pandas as pd
from dotenv import load_dotenv
from typing import List, Dict

# Load environment variables
load_dotenv()

# Constants for the self-hosted model
API_URL = "https://deepseek-r1-qwen-14b-w4a16-maas-apicast-production.apps.prod.rhoai.rh-aiservices-bu.com:443"
API_KEY = "bd639419826367f606eabb2e09f22490"  # This should ideally be in your .env file

# NVD API constants
NVD_API_URL = "https://services.nvd.nist.gov/rest/json/cves/2.0"
NVD_API_KEY = os.getenv("NVD_API_KEY")
MAX_CVE_PER_BATCH = 3  # Limit number of CVEs per batch to manage token count
MAX_DESCRIPTION_LENGTH = 200  # Limit length of descriptions
MAX_PACKAGES_SHOWN = 3  # Limit number of affected packages shown

# %%
# Custom LLM class to replace ChatOpenAI
class SelfHostedLLM:
    def __init__(self, api_url, api_key, model="r1-qwen-14b-w4a16", temperature=0.2):
        self.api_url = api_url
        self.api_key = api_key
        self.model = model
        self.temperature = temperature
    
    def invoke(self, prompt_data):
        prompt_text = prompt_data["cve_details"]
        
        messages = [
            {"role": "system", "content": """You are an expert cybersecurity analyst specializing in vulnerability assessment. 
             Your task is to analyze CVEs and identify which ones are code-related based on specific criteria."""},
            {"role": "user", "content": prompt_text}
        ]
        
        try:
            response = requests.post(
                url=self.api_url + '/v1/chat/completions',
                json={
                    "model": self.model,
                    "messages": messages,
                    "max_tokens": 4000,
                    "temperature": self.temperature
                },
                headers={'Authorization': 'Bearer ' + self.api_key}
            )
            
            if response.status_code == 200:
                completion = response.json()
                return type('obj', (object,), {
                    'content': completion.get('choices', [{}])[0].get('message', {}).get('content', '')
                })
            else:
                print(f"Error: API returned status code {response.status_code}")
                print(f"Response: {response.text}")
                return type('obj', (object,), {'content': f"Error: {response.status_code}"})
        
        except Exception as e:
            print(f"Exception during API call: {e}")
            return type('obj', (object,), {'content': f"Error: {str(e)}"})

# %%
def fetch_cves(limit=10000):
    base_url = "https://access.redhat.com/labs/securitydataapi/cve.json"
    cves = []
    page = 1
    per_page = 100  # Number of CVEs per page (max allowed by the API)

    while len(cves) < limit:
        url = f"{base_url}?page={page}&per_page={per_page}"
        response = requests.get(url)
        
        if response.status_code != 200:
            print(f"Failed to fetch data: {response.status_code}")
            break
        
        data = response.json()
        if not data:
            break  # No more data available
        
        cves.extend(data)
        page += 1

        print(f"Fetched {len(cves)} CVEs so far...")

        if len(data) < per_page:
            break  # No more pages available

    return cves[:limit]

# %%
def extract_year_from_cve(cve_id):
    """
    Extracts the year from a CVE identifier.

    :param cve_id: A string representing the CVE ID (e.g., "CVE-2022-49043").
    :return: The year as an integer (e.g., 2022).
    """
    # Split the CVE ID by '-' and get the second part (the year)
    try:
        year = int(cve_id.split('-')[1])
        return year
    except (IndexError, ValueError) as e:
        print(f"Error extracting year from CVE ID: {e}")
        return None

# %%
def fetch_cve_details(cve_ids: List[str]) -> List[Dict]:
    """
    Fetch CVE details from the NVD API for a given list of CVE IDs using an API key.
    """
    cve_details = []

    for cve_id in cve_ids:
        try:
            # Make the API request with the API key
            headers = {"apiKey": NVD_API_KEY} if NVD_API_KEY else {}
            response = requests.get(f"{NVD_API_URL}?cveId={cve_id}", headers=headers)
            response.raise_for_status()  # Raise an exception for HTTP errors

            # Parse the response
            data = response.json()
            vulnerabilities = data.get("vulnerabilities", [])

            if not vulnerabilities:
                print(f"No data found for CVE: {cve_id}")
                continue

            # Extract relevant details
            for vuln in vulnerabilities:
                cve_data = vuln.get("cve", {})
                
                # Get the description
                descriptions = cve_data.get("descriptions", [])
                description = next((desc["value"] for desc in descriptions if desc.get("lang") == "en"), 
                                  "No description available")
                
                # Get metrics information including CVSS score
                metrics = cve_data.get("metrics", {})
                severity_level = "Unknown"
                cvss_score = "Unknown"
                
                # Try to extract CVSS metrics in order of preference
                if "cvssMetricV31" in metrics:
                    cvss_data = metrics["cvssMetricV31"][0]["cvssData"]
                    severity_level = cvss_data.get("baseSeverity", "Unknown")
                    cvss_score = str(cvss_data.get("baseScore", "Unknown"))
                elif "cvssMetricV30" in metrics:
                    cvss_data = metrics["cvssMetricV30"][0]["cvssData"]
                    severity_level = cvss_data.get("baseSeverity", "Unknown")
                    cvss_score = str(cvss_data.get("baseScore", "Unknown"))
                elif "cvssMetricV2" in metrics:
                    cvss_data = metrics["cvssMetricV2"][0]["cvssData"]
                    severity_level = cvss_data.get("baseSeverity", "Unknown")
                    cvss_score = str(cvss_data.get("baseScore", "Unknown"))
                
                # Get affected packages and potential attack vectors
                affected_packages = []
                
                configurations = cve_data.get("configurations", [])
                for config in configurations:
                    nodes = config.get("nodes", [])
                    for node in nodes:
                        cpe_matches = node.get("cpeMatch", [])
                        for cpe_match in cpe_matches:
                            affected_packages.append(cpe_match.get("criteria", "Unknown"))
                            
                # Get weakness information that might indicate vulnerability type
                weakness_info = []
                weaknesses = cve_data.get("weaknesses", [])
                for weakness in weaknesses:
                    for desc in weakness.get("description", []):
                        weakness_info.append(desc.get("value", ""))
                
                cve_details.append({
                    "cve_id": cve_id,
                    "description": description,
                    "severity": {
                        "level": severity_level,
                        "score": cvss_score
                    },
                    "affected_packages": affected_packages,
                    "weakness_info": weakness_info
                })

        except requests.exceptions.RequestException as e:
            print(f"Error fetching data for CVE {cve_id}: {e}")

    return cve_details

# %%
def truncate_text(text, max_length):
    """Truncate text to a maximum length and add ellipsis if truncated."""
    if len(text) <= max_length:
        return text
    return text[:max_length] + "..."

# %%
def format_cve_details_for_llm(cve_details: List[Dict]) -> str:
    """
    Format CVE details in a token-efficient way for LLM analysis.
    """
    formatted_details = []
    
    for cve in cve_details:
        # Truncate description to control token count
        description = truncate_text(cve['description'], MAX_DESCRIPTION_LENGTH)
        
        cve_str = f"CVE ID: {cve['cve_id']}\n"
        cve_str += f"Description: {description}\n"
        cve_str += f"Severity: {cve['severity']['level']} (Score: {cve['severity']['score']})\n"
        
        # Format affected packages more efficiently
        if cve['affected_packages']:
            # Only include a limited number of packages
            packages = cve['affected_packages'][:MAX_PACKAGES_SHOWN]
            # Extract key components from CPE strings to save tokens
            simplified_packages = []
            for pkg in packages:
                # Extract product and vendor from CPE string if possible
                match = re.search(r':([^:]+):([^:]+):', pkg)
                if match:
                    vendor, product = match.groups()
                    simplified_packages.append(f"{vendor}/{product}")
                else:
                    # Use the last part of the CPE if parsing fails
                    parts = pkg.split(':')
                    simplified_packages.append(parts[-1] if len(parts) > 2 else pkg)
            
            cve_str += "Affected Components: " + ", ".join(simplified_packages)
            if len(cve['affected_packages']) > MAX_PACKAGES_SHOWN:
                cve_str += f" (+{len(cve['affected_packages']) - MAX_PACKAGES_SHOWN} more)"
            cve_str += "\n"
        
        # Include only the most relevant weakness info
        if cve['weakness_info']:
            # Just use the first weakness to save tokens
            cve_str += f"Weakness: {truncate_text(cve['weakness_info'][0], 100)}\n"
                
        formatted_details.append(cve_str)
    prompt_template = """
You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.

## What Makes a CVE Code-Related
A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code-related if it explicitly involves one of these languages:

1. Go
2. Python 
3. Dockerfile
4. Java
5. TypeScript
6. JavaScript

If the vulnerability is in any other language or technology, it should NOT be classified as code-related, even if it matches the categories listed below.

The following categories are only considered code-related if they specifically involve one of the six languages listed above:

1. Remote Code Execution (RCE)
2. Code/Command Injection
3. SQL Injection
4. Cross-Site Scripting (XSS)
5. Deserialization vulnerabilities
6. Buffer Overflows
7. Format String vulnerabilities
8. Memory corruption issues
9. Path traversal that could lead to code execution
10. Arbitrary file inclusion
11. Logic flaws in application code
12. Implementation flaws in libraries, frameworks, or programming languages
13. Race conditions affecting code execution
14. Improper cryptographic implementations
15. Client-side/server-side request forgery
16. Coding errors leading to memory corruption
17. Input validation failures
18. Insecure API implementations or calls
19. Authentication/authorization bypass due to code flaws
20. Use-after-free vulnerabilities
21. Integer overflow/underflow
22. Double-free vulnerabilities
23. Null pointer dereference
24. Uninitialized memory usage
25. Out-of-bounds read/write
26. DOM-based XSS
27. Prototype pollution
28. XML External Entity (XXE) processing
29. Cross-Site Request Forgery (CSRF)
30. HTTP request smuggling

## CVE Details to Analyze:
"""
    prompt_template += "\n" + "-" * 20 + "\n".join(formatted_details)
    
    prompt_template += """

## Response Format:
Return a JSON array of objects with the following format:
{
  "cve_id": "The CVE identifier",
  "code_related": true/false,
  "exclusion_reason": "If not code-related, specify the reason or indicate that it doesn't involve one of the six specified languages. Leave blank if code-related."
}

## Exclusion Criteria (if not code-related):
1. Not in specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript)
2. Configuration errors only
3. Physical security issues
4. Social engineering without code exploits
5. Default credentials
6. Policy/procedure violations
7. Expired certificates
8. Denial of Service that doesn't involve code manipulation
9. Hardware-based issues with no software component
10. Documentation errors or insufficient warnings
"""
    
    return prompt_template

# %%
def chunk_cve_ids(cve_ids, batch_size=MAX_CVE_PER_BATCH):
    """Split CVE IDs into smaller batches for processing."""
    for i in range(0, len(cve_ids), batch_size):
        yield cve_ids[i:i + batch_size]

def analyze_code_related_cves(cve_ids: List[str]) -> Dict:
    """
    Analyze CVEs in batches to manage token limits.
    """
    all_results = []
    all_cve_statuses = []  # List to store status of all CVEs for Excel
    total_analyzed = 0
    
    # Initialize the LLM with the self-hosted model
    llm = SelfHostedLLM(api_url=API_URL, api_key=API_KEY)
    
    # Process CVEs in batches to manage token limits
    batches = list(chunk_cve_ids(cve_ids))
    print(f"Processing {len(cve_ids)} CVEs in {len(batches)} batches...")
    
    for i, batch in enumerate(batches):
        print(f"\nProcessing batch {i+1}/{len(batches)} ({len(batch)} CVEs)...")
        
        # Fetch details for this batch
        cve_details = fetch_cve_details(batch)
        total_analyzed += len(cve_details)
        
        if not cve_details:
            print("No details found for this batch")
            continue
        
        # Format the CVE details for the LLM
        formatted_details = format_cve_details_for_llm(cve_details)

        # **Debug Statement: Print Input to LLM**
        print("\n=== Input to LLM ===")
        print(formatted_details[:500] + "..." if len(formatted_details) > 500 else formatted_details)
        print("====================\n")
        
        # Invoke the LLM with the CVE details
        print(f"Analyzing batch {i+1}...")
        result = llm.invoke({"cve_details": formatted_details}).content

        # **Debug Statement: Print Raw LLM Output**
        print("\n=== Raw LLM Output ===")
        print(result[:500] + "..." if len(result) > 500 else result)
        print("======================\n")
        
        # Try to parse the result as JSON
        try:
            # First, try to find JSON in the response
            json_match = re.search(r'\[[^\[\]]*(\\[[^\[\]]*\\][^\[\]]*)*\]', result)
            if json_match:
                parsed_result = json.loads(json_match.group(0))
            else:
                # Try looking for JSON array pattern
                json_match = re.search(r'\[\s*\{.*?\}\s*\]', result, re.DOTALL)
                if json_match:
                    parsed_result = json.loads(json_match.group(0))
                else:
                    # Last resort: try to parse the whole response
                    parsed_result = json.loads(result)
                
            # Store all CVE results for Excel
            all_cve_statuses.extend(parsed_result)
            
            # Store code-related CVEs for summary output
            code_related = [cve for cve in parsed_result if isinstance(cve, dict) and cve.get('code_related') is True]
            all_results.extend(code_related)
            
            print(f"Found {len(code_related)} code-related CVEs in this batch")
            
        except json.JSONDecodeError:
            print("Warning: Could not parse result as JSON.")
            print("Raw output (first 100 chars):", result[:100] + "...")
            # Add entries with error status for the current batch
            for cve_id in batch:
                all_cve_statuses.append({
                    "cve_id": cve_id,
                    "code_related": "Error",
                    "exclusion_reason": "Failed to parse LLM response"
                })
    
    # Fix if the item is not a dict
    # Before calling write_to_excel, add a validation step:
    validated_statuses = []
    for item in all_cve_statuses:
        if isinstance(item, dict):
            validated_statuses.append(item)
        else:
            # Log the problematic item
            print(f"Warning: Found non-dictionary item in all_cve_statuses: {item}")
            # You could also create a proper dictionary for this item
            validated_statuses.append({
                "cve_id": "unknown",
                "code_related": "Error",
                "exclusion_reason": f"Invalid data type: {type(item)}"
            })
    # Write results to Excel
    write_to_excel(validated_statuses)
    
    return {
        "code_related_cves": all_results,
        "total_analyzed": total_analyzed,
        "total_code_related": len(all_results)
    }

# %%
def write_to_excel(cve_statuses: List[Dict]):
    """
    Write CVE analysis results to an Excel file.
    """
    # Create DataFrame
    df = pd.DataFrame(cve_statuses)
    
    # Ensure column order and handle missing columns
    columns = ["cve_id", "code_related", "exclusion_reason"]
    for col in columns:
        if col not in df.columns:
            df[col] = ""
    
    # Reorder columns
    df = df[columns]
    
    # Fill empty exclusion reasons for code-related CVEs with "-"
    df.loc[df["code_related"] == True, "exclusion_reason"] = "-"
    
    # Write to Excel
    file_name = "cve_analysis_results_r1_qwen.xlsx"
    df.to_excel(file_name, index=False, sheet_name="CVE Analysis")
    
    print(f"\nResults written to '{file_name}'")
    print(f"Total CVEs processed: {len(df)}")
    print(f"Code-related CVEs: {sum(df['code_related'] == True)}")
    print(f"Non-code-related CVEs: {sum(df['code_related'] == False)}")
    print(f"Error processing: {sum(df['code_related'] == 'Error')}")

# %%
# Fetch CVEs
print("Fetching CVEs from Red Hat Security Data API...")
cves = fetch_cves(limit=2000)  # Start with a small number for testing

# Extract CVE IDs
final_cves = [cve['CVE'] for cve in cves]
print(f"Extracted {len(final_cves)} CVE IDs")

# Analyze code-related CVEs
print("Starting analysis of code-related CVEs...")
analysis_results = analyze_code_related_cves(final_cves)

# Print results
print("\n----- ANALYSIS RESULTS -----")
print(f"Total CVEs analyzed: {analysis_results.get('total_analyzed', 0)}")

if 'total_code_related' in analysis_results:
    print(f"Code-related CVEs found: {analysis_results['total_code_related']}")
    
    # Print each code-related CVE in a readable format
    for i, cve in enumerate(analysis_results['code_related_cves'], 1):
        print(f"\n{i}. {cve['cve_id']}")
        print(f"   Code-related: {cve.get('code_related', True)}")
        # Only print other fields if they exist
        if 'vulnerability_type' in cve:
            print(f"   Vulnerability Type: {cve.get('vulnerability_type', 'Unknown')}")
        if 'affected_component' in cve:
            print(f"   Affected Component: {cve.get('affected_component', 'Unknown')}")
        if 'requires_code_change' in cve:
            print(f"   Requires Code Change: {cve.get('requires_code_change', True)}")
        if 'severity' in cve:
            print(f"   Severity: {cve.get('severity', {}).get('level', 'Unknown')} ({cve.get('severity', {}).get('score', 'Unknown')})")
else:
    print("No structured results available or parsing error occurred.")
# Out:
# Fetching CVEs from Red Hat Security Data API...
# Fetched 100 CVEs so far...
# Fetched 200 CVEs so far...
# Fetched 300 CVEs so far...
# Fetched 400 CVEs so far...
# Fetched 500 CVEs so far...
# Fetched 600 CVEs so far...
# Fetched 700 CVEs so far...
# Fetched 800 CVEs so far...
# Fetched 900 CVEs so far...
# Fetched 1000 CVEs so far...
# Fetched 1100 CVEs so far...
# Fetched 1200 CVEs so far...
# Fetched 1300 CVEs so far...
# Fetched 1400 CVEs so far...
# Fetched 1500 CVEs so far...
# Fetched 1600 CVEs so far...
# Fetched 1700 CVEs so far...
# Fetched 1800 CVEs so far...
# Fetched 1900 CVEs so far...
# Fetched 2000 CVEs so far...
# Extracted 2000 CVE IDs
# Starting analysis of code-related CVEs...
# Processing 2000 CVEs in 667 batches...
#
# Processing batch 1/667 (3 CVEs)...
# No data found for CVE: CVE-2024-36347
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 1...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze the given CVEs to determine if they are code-related based on the specified criteria. Let's go through each CVE one by one.
#
# Starting with CVE-2025-1080. The description mentions LibreOffice supporting Office URI Schemes and adding a specific scheme 'vnd.libreoffice.command'. The severity is unknown, and the weakness is CWE-20, which relates to command injection. Now, I need to check if this involves any of the specified languages: Go, Python, Dockerfile, Java,...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 2/667 (3 CVEs)...
# /tmp/ipykernel_72127/2758727648.py:52: FutureWarning: Possible nested set at position 14
#   json_match = re.search(r'\[[^\[\]]*(\\[[^\[\]]*\\][^\[\]]*)*\]', result)
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 2...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-1943. The description mentions memory safety bugs in Firefox and Thunderbird, leading to memory corruption. The weakness is CWE-122, which is about improper handling of memory, often leading to buffer overflows or other memory issues. Firefox is written in C++, which isn't one of the specified languages (Go, Python, ...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 3/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 3...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze the given CVEs to determine which are code-related based on the specified criteria. Let's go through each one step by step.
#
# First, looking at CVE-2025-1936. The description mentions "jar: URLs retrieve local file content packaged in a ZIP archive." The issue is about how the null and everything after it was ignored when retrieving content. The term "jar" here refers to Java ARchive files, which are definitely related to Java. Since Java is one of the specified...
# ======================
#
# Found 2 code-related CVEs in this batch
#
# Processing batch 4/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 4...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-1935. The description mentions a web page tricking a user into setting the site as the default handler for a custom URL protocol. The affected software is Firefox and Thunderbird. The weakness is CWE-451, which relates to improper handling of protocol handlers.
#
# I need to check if this involves any of the specified ...
# ======================
#
# Found 1 code-related CVEs in this batch
#
# Processing batch 5/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 5...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-1931. The description mentions a use-after-free in the content process of a WebTransport connection, leading to a crash. Use-after-free is a common memory corruption issue, which falls under category 20 in the list. The affected software is Firefox, which is primarily written in C++ and JavaScript. Since JavaScript...
# ======================
#
# Found 3 code-related CVEs in this batch
#
# Processing batch 6/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 6...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let's take each one step by step.
#
# Starting with CVE-2025-1930. The description mentions a use-after-free vulnerability in the Browser process on Windows. Use-after-free is a type of memory corruption issue, which falls under category 20 in the list. The weakness is CWE-416, which is related to use-after-free. Now, the vulnerability is in the Browser process, but the description...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 7/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 7...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze the given CVEs to determine if they are code-related based on the specified criteria. Let's go through each one step by step.
#
# First, I'll look at CVE-2025-1866. The description mentions an "Improper Restriction of Operations within the Bounds of a Memory Buffer" vulnerability in warmcat libwebsockets. This is a classic buffer overflow issue, which falls under CWE-119. The categories include buffer overflows, which is one of the code-related criteria. Now, I ne...
# ======================
#
# Found 1 code-related CVEs in this batch
#
# Processing batch 8/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 8...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-27219. The description mentions the CGI gem for Ruby. Ruby isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript), so this should be excluded. The vulnerability is a Denial of Service, but since it's in Ruby, it's not code-related under the given criteria.
#
# Next, CVE-2025-27221 in...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 9/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 9...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2022-49733. The description mentions a race condition in the Linux kernel's ALSA PCM OSS SNDCTL_DSP_SYNC. The weakness is CWE-362, which is related to race conditions. Now, the Linux kernel is written in C, which isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript). So, even though i...
# ======================
#
# Found 1 code-related CVEs in this batch
#
# Processing batch 10/667 (3 CVEs)...
# No data found for CVE: CVE-2024-12225
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 10...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these two CVEs and determine if they're code-related based on the given criteria. Let me start by understanding the task.
#
# First, the criteria for a code-related CVE are that it must involve one of the specified languages: Go, Python, Dockerfile, Java, TypeScript, or JavaScript. Even if the CVE falls into one of the listed categories, it's only code-related if it's in one of these languages.
#
# Looking at the first CVE: CVE-2025-1686. The description mentions a v...
# ======================
#
# Found 1 code-related CVEs in this batch
#
# Processing batch 11/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 11...
#
# === Raw LLM Output ===
# <think>
# Alright, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-21760. The description mentions the Linux kernel and a function called ndisc_send_skb(). It says that this function can be called without RTNL or RCU held, and they fixed it by acquiring rcu_read_lock(). The weakness is CWE-416, which I think relates to race conditions. Now, the task is to see if this is code-re...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 12/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 12...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2024-57974. The description mentions the Linux kernel dealing with a race condition between UDP socket address change and rehash. The Linux kernel is written in C, right? But the specified languages for code-related are Go, Python, Dockerfile, Java, TypeScript, and JavaScript. Since C isn't on the list, this might not be...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 13/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 13...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-21746. The description mentions the Linux kernel and a fix for a crash when enabling a pass-through port. The issue arises due to an interrupt arriving before some process completes. The severity is unknown. Now, the Linux kernel is written in C, which isn't one of the specified languages (Go, Python, Dockerfile, J...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 14/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 14...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-21778. The description mentions the Linux kernel and specifically talks about the mmap() function of the persistent ring buffer. mmap() is a system call in Unix-like systems, which is part of the kernel. The vulnerability here is about not allowing mmap() on a trace instance buffer. Since this is related to the kerne...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 15/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 15...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs to determine if they are code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2024-58019. The description mentions the Linux kernel's GSP message queue. It talks about advancing the read pointer of GSP messages, which consist of a header, RPC, and data. The issue seems to be in the kernel's handling of these messages. Since the Linux kernel is written in C, and C isn't one of the specified langua...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 16/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 16...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-21736. The description mentions an int overflow in nilfs_fiemap(). The issue is with integer overflow, which is a common code-related vulnerability. The Linux kernel is written in C, but the criteria specifies that only certain languages are considered. C isn't on the list, so even though it's a code issue, it's no...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 17/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 17...
#
# === Raw LLM Output ===
# <think>
# Okay, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-21718. The description mentions the Linux kernel and talks about fixing timer races against user threads. It says that Rose timers only acquire the socket spinlock without checking if the socket is owned. Hmm, the Linux kernel is written in C, right? But the specified languages for code-related issues are Go, Python, D...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 18/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 18...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2024-57852. The description mentions the Linux kernel and a commit related to handling a missing SCM device. The commit message talks about fixing a NULL-pointer dereference. Now, a NULL pointer dereference is one of the exclusion criteria listed, specifically point 23. But wait, the criteria for code-related includes t...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 19/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 19...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2024-58016. The description mentions the Linux kernel's 'safesetid' function and a buffer write issue. The syzbot is trying to write a large buffer to a sysfs entry. Now, sysfs is part of the Linux kernel, which is written in C. The languages we're considering are Go, Python, Dockerfile, Java, TypeScript, and JavaScript...
# ======================
#
# Warning: Could not parse result as JSON.
# Raw output (first 100 chars): <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on t...
#
# Processing batch 20/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 20...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2024-57991. The description mentions the Linux kernel and a soft lockup in rtw89_entity_recalc_mgnt_roles(). Soft lockups are usually related to kernel issues, possibly due to race conditions or infinite loops. The Linux kernel is written in C, which isn't one of the specified languages (Go, Python, Dockerfile, Java, Ty...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 21/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 21...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-21768. The description mentions the Linux kernel and issues with lwtunnels. It talks about fixing dst ref loops in rpl, seg6, and ioam6. The problem seems to be with network transformations and potential loops. The severity is unknown. Now, the task is to see if this is code-related. The languages we're considering a...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 22/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 22...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze the given CVEs to determine if they are code-related based on the specified criteria. Let's go through each one step by step.
#
# First, looking at CVE-2025-21747. The description mentions the Linux kernel and a fix in the drm/ast driver related to enabling the video signal. The issue seems to be a timeout problem. The Linux kernel is written in C, which isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript). So, even though it...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 23/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 23...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2024-58001. The description mentions the Linux kernel and converting ocfs2 to use folios. Mark did a conversion, but I don't see any mention of specific programming languages like Go, Python, etc. It seems to be a kernel issue, possibly related to file systems or memory management. Since it's in the Linux kernel, which is...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 24/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 24...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-21754. The description mentions a fix in the Linux kernel related to btrfs and ordered extent after a transaction abort. The issue arises during a direct IO write. The Linux kernel is written in C, which isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript). So, even though it's ...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 25/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 25...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-21733. The description mentions the Linux kernel's tracing/osnoise component. It talks about fixing tracepoints when a timerlat tracer is started with a specific option. The issue seems to be in the kernel, which is written in C. But the list of languages we're considering are Go, Python, Dockerfile, Java, TypeScri...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 26/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 26...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-21714. The description mentions the Linux kernel's RDMA/mlx5 component. The issue is about fixing an implicit ODP use after free. The weakness is CWE-416, which is related to use-after-free vulnerabilities. Now, the Linux kernel is written in C, which isn't one of the specified languages (Go, Python, Dockerfile, Java...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 27/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 27...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2024-57997. The description mentions a memory allocation issue in the Linux kernel related to the wcn->chan_survey. The mention of KASAN, which I know is a memory debugging tool for kernel space, suggests this is a kernel issue. The Linux kernel is written in C, which isn't one of the specified languages (Go, Python, etc....
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 28/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 28...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-21725. The description mentions the Linux kernel and specifically talks about the 'smb' client fixing an 'oops' due to an unset link speed. It refers to NETWORK_INTERFACE_INFO::LinkSpeed not being set. Hmm, the Linux kernel is written in C, right? But the criteria only includes Go, Python, Dockerfile, Java, TypeScri...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 29/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 29...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-21721. The description mentions the Linux kernel and specifically talks about nilfs2 and handling errors with nilfs_prepare_chunk(). The patch is about rename operations. Now, the Linux kernel is written in C, right? So, the vulnerability is in C code. But the specified languages for code-related are Go, Python, Do...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 30/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 30...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2024-57993. The description mentions the Linux kernel and a fix in the HID driver for thrustmaster. The issue was a type mismatch in the USB handling. Since the Linux kernel is written in C, and C isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript), this CVE isn't code-related. It's...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 31/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 31...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-21734. The description mentions the Linux kernel's fastrpc driver. It talks about fixing a copy buffer page size issue. The problem is in the kernel, which is written in C. Since C isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript), this CVE isn't code-related. The exclusion r...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 32/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 32...
#
# === Raw LLM Output ===
# <think>
# Okay, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-21743. The description mentions a fix in the Linux kernel's usbnet module for an overflow in DPE length check. The severity is high, and the weakness is CWE-125, which relates to buffer overflow. Now, the vulnerability involves the Linux kernel, which is written in C. Since C isn't one of the specified languages (Go, Py...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 33/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 33...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze the given CVEs to determine if they are code-related based on the specified criteria. Let's go through each one step by step.
#
# First, looking at CVE-2025-21764. The description mentions the Linux kernel and issues with ndisc_alloc_skb(). The problem is about RCU protection not being held when the function is called. RCU stands for Read-Copy-Update, which is a synchronization mechanism in the Linux kernel. This seems to be a concurrency issue in the kernel code....
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 34/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 34...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2024-57998. The description mentions a buffer overflow in the Linux kernel's _read_freq() function. Buffer overflow is one of the code-related categories, specifically number 6: buffer overflow. However, the Linux kernel is written in C, which isn't one of the six specified languages (Go, Python, Dockerfile, Java, TypeScr...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 35/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 35...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2024-57995. The description mentions the Linux kernel and a function called ath12k_mac_assign_vif_to_vdev(). It talks about a read pointer issue after freeing something. The term "read pointer" makes me think of memory management, possibly a buffer overflow or use-after-free scenario. However, the Linux kernel is written...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 36/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 36...
#
# === Raw LLM Output ===
# <think>
# Alright, so I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2025-21796. The description mentions the Linux kernel and talks about releasing acl_access and acl_default. It seems like this is related to memory management in the kernel. The weakness is CWE-416, which is about use-after-free. Now, the Linux kernel is written in C, which isn't one of the specified languages (Go, Py...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 37/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 37...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze the given CVEs to determine if they are code-related based on the specified criteria. Let me go through each one step by step.
#
# First, looking at CVE-2025-21786. The description mentions the Linux kernel and a commit related to workqueue handling. The vulnerability is about putting the pwq after detaching the rescuer from the pool. The severity is high, and the weakness is CWE-416, which relates to a race condition. Now, race conditions are one of the categorie...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 38/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 38...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2024-58005. The description mentions a change to kvalloc() in eventlog/acpi.c within the Linux kernel. The issue was reported on HPE ProLiant D320. The problem seems to be related to memory allocation. Since the Linux kernel is written in C, and C isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScr...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 39/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 39...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2025-21777. The description mentions the Linux kernel's ring-buffer and validating the persistent meta data subbuf array. The Linux kernel is written in C, which isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript). So, even though it's a buffer validation issue, since it's in C, it ...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 40/667 (3 CVEs)...
#
# === Input to LLM ===
#
# ...
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 658...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2024-8676. The description mentions CRI-O and container checkpoint restoration. CRI-O is related to Docker and container runtime, which is Dockerfile. The vulnerability involves taking a checkpoint and restoring it, which could lead to issues. Since Dockerfile is one of the specified languages, this should be code-related...
# ======================
#
# Found 1 code-related CVEs in this batch
#
# Processing batch 659/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 659...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's go through each one step by step.
#
# Starting with CVE-2024-11699. The description mentions memory safety bugs in Firefox, which is known to be written in C++. The weakness is CWE-94, which relates to memory corruption. Since C++ isn't one of the specified languages (Go, Python, Dockerfile, Java, TypeScript, JavaScript), this CVE isn't code-related. The exclusion reason is th...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 660/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 660...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's take each one step by step.
#
# Starting with CVE-2024-11698. The description mentions a flaw in handling fullscreen transitions causing the app to get stuck in fullscreen mode when a modal dialog is opened. The severity is critical, but the description doesn't specify any code implementation issues. It sounds more like a logic flaw or a bug in the application's state manageme...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 661/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 661...
#
# === Raw LLM Output ===
# <think>
# Okay, I need to analyze these three CVEs to determine if they are code-related based on the given criteria. Let's take each one step by step.
#
# Starting with CVE-2024-11697. The description mentions handling keypress events and bypassing a confirmation dialog leading to malicious code execution. The weakness is CWE-94, which is about bypassing confirmation dialogs. I'm thinking, does this involve any specific programming language? The description doesn't mention any particular language li...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 662/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 662...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze the given CVEs to determine if they're code-related based on the specified criteria. Let's go through each one step by step.
#
# Starting with CVE-2024-11694. The description mentions a DOM-based XSS issue in the Web Compatibility extension. DOM-based XSS is one of the categories listed (category 27: DOM-based XSS). Now, I need to check if this involves any of the six specified languages. The vulnerability is related to JavaScript since DOM-based XSS typically inv...
# ======================
#
# Found 1 code-related CVEs in this batch
#
# Processing batch 663/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 663...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2024-11700. The description mentions tapjacking on malicious websites leading to users approving external app launches without knowing. The weakness is CWE-1021, which is about UI redress attacks. Tapjacking is a type of UI redress where the interface is manipulated to trick the user. This doesn't involve any specific p...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 664/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 664...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2024-11691. The description mentions an out-of-bounds write and memory corruption in Apple's GPU driver. The vulnerability is in the GPU driver, which is a hardware component. The languages involved here are not specified, and since Apple's drivers are typically written in languages like C or C++, which aren't on the li...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 665/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 665...
#
# === Raw LLM Output ===
# <think>
# Okay, so I need to analyze these three CVEs and determine if they're code-related based on the given criteria. Let me go through each one step by step.
#
# Starting with CVE-2023-2142. The description mentions that it's in Nunjucks versions prior to 3.2.4. The issue is about bypassing autoescape functionality when there are two user-controlled parameters. The weakness is CWE-79, which is related to XSS. Now, I need to check if Nunjucks is implemented in one of the specified languages: Go, P...
# ======================
#
# Found 1 code-related CVEs in this batch
#
# Processing batch 666/667 (3 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 666...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze these three CVEs to determine if they're code-related based on the given criteria. Let's take each one step by step.
#
# Starting with CVE-2024-11403. The description mentions an out-of-bounds read/write in LibJXL. The vulnerability occurs in the JPEG decoder used by the JPEG XL encoder during JPEG recompression. The weakness is CWE-125, which relates to out-of-bounds issues. Now, I need to check if this involves any of the specified languages: Go, Python, Dockerf...
# ======================
#
# Found 0 code-related CVEs in this batch
#
# Processing batch 667/667 (2 CVEs)...
#
# === Input to LLM ===
#
# You are an expert cybersecurity analyst specializing in vulnerability assessment. Your task is to analyze a list of CVE (Common Vulnerabilities and Exposures) identifiers and identify which ones are specifically code-related.
#
# ## What Makes a CVE Code-Related
# A code-related CVE involves vulnerabilities directly attributable to software implementation issues in specific programming languages rather than configuration, physical security, or policy problems. A vulnerability is ONLY considered code...
# ====================
#
# Analyzing batch 667...
#
# === Raw LLM Output ===
# <think>
# Alright, I need to analyze the given CVEs to determine if they are code-related based on the specified criteria. Let's go through each CVE one by one.
#
# Starting with CVE-2024-53098. The description mentions the Linux kernel's drm/xe/ufence component. The issue is about accessing an address that might be bogus. The function uses access_ok(), which only checks for address overflow. The fix involves prefetching the ufence addr to catch bogus addresses.
#
# Now, the Linux kernel is primarily w...
# ======================
#
# Found 0 code-related CVEs in this batch
# Warning: Found non-dictionary item in all_cve_statuses: 64
# Warning: Found non-dictionary item in all_cve_statuses: 6
# Warning: Found non-dictionary item in all_cve_statuses: 1
#
# Results written to 'cve_analysis_results_r1_qwen.xlsx'
# Total CVEs processed: 1977
# Code-related CVEs: 91
# Non-code-related CVEs: 1871
# Error processing: 15
#
# ----- ANALYSIS RESULTS -----
# Total CVEs analyzed: 1989
# Code-related CVEs found: 91
#
# 1. CVE-2025-1936
#    Code-related: True
#
# 2. CVE-2025-1942
#    Code-related: True
#
# 3. CVE-2025-1934
#    Code-related: True
#
# 4. CVE-2025-1931
#    Code-related: True
#
# 5. CVE-2025-1933
#    Code-related: True
#
# 6. CVE-2025-1932
#    Code-related: True
#
# 7. CVE-2025-23368
#    Code-related: True
#
# 8. CVE-2025-1801
#    Code-related: True
#
# 9. CVE-2025-1686
#    Code-related: True
#
# 10. CVE-2025-27148
#    Code-related: True
#
# 11. CVE-2025-27144
#    Code-related: True
#
# 12. CVE-2025-1634
#    Code-related: True
#
# 13. CVE-2024-4028
#    Code-related: True
#
# 14. CVE-2025-1302
#    Code-related: True
#
# 15. CVE-2025-25290
#    Code-related: True
#
# 16. CVE-2025-25289
#    Code-related: True
#
# 17. CVE-2025-25288
#    Code-related: True
#
# 18. CVE-2025-25285
#    Code-related: True
#
# 19. CVE-2024-3220
#    Code-related: True
#
# 20. CVE-2024-52577
#    Code-related: True
#
# 21. CVE-2025-26791
#    Code-related: True
#
# 22. CVE-2025-1244
#    Code-related: True
#
# 23. CVE-2025-1247
#    Code-related: True
#
# 24. CVE-2025-24970
#    Code-related: True
#
# 25. CVE-2025-25247
#    Code-related: True
#
# 26. CVE-2025-22867
#    Code-related: True
#
# 27. CVE-2025-1011
#    Code-related: True
#
# 28. CVE-2025-24860
#    Code-related: True
#
# 29. CVE-2025-23015
#    Code-related: True
#
# 30. CVE-2025-24898
#    Code-related: True
#
# 31. CVE-2025-0938
#    Code-related: True
#
# 32. CVE-2025-23367
#    Code-related: True
#
# 33. CVE-2024-0137
#    Code-related: True
#
# 34. CVE-2024-0136
#    Code-related: True
#
# 35. CVE-2024-0135
#    Code-related: True
#
# 36. CVE-2025-22865
#    Code-related: True
#
# 37. CVE-2024-45340
#    Code-related: True
#
# 38. CVE-2025-24150
#    Code-related: True
#
# 39. CVE-2025-24357
#    Code-related: True
#
# 40. CVE-2025-21502
#    Code-related: True
#
# 41. CVE-2025-22150
#    Code-related: True
#
# 42. CVE-2025-0377
#    Code-related: True
#
# 43. CVE-2025-23184
#    Code-related: True
#
# 44. CVE-2025-0752
#    Code-related: True
#
# 45. CVE-2025-24010
#    Code-related: True
#
# 46. CVE-2024-11218
#    Code-related: True
#
# 47. CVE-2025-23207
#    Code-related: True
#
# 48. CVE-2025-23366
#    Code-related: True
#
# 49. CVE-2024-56374
#    Code-related: True
#
# 50. CVE-2024-55459
#    Code-related: True
#
# 51. CVE-2025-0240
#    Code-related: True
#
# 52. CVE-2025-21614
#    Code-related: True
#
# 53. CVE-2025-21613
#    Code-related: True
#
# 54. CVE-2024-56332
#    Code-related: True
#
# 55. CVE-2024-52046
#    Code-related: True
#
# 56. CVE-2024-56326
#    Code-related: True
#
# 57. CVE-2024-56201
#    Code-related: True
#
# 58. CVE-2024-56334
#    Code-related: True
#
# 59. CVE-2024-56337
#    Code-related: True
#
# 60. CVE-2024-12801
#    Code-related: True
#
# 61. CVE-2024-12798
#    Code-related: True
#
# 62. CVE-2024-53270
#    Code-related: True
#
# 63. CVE-2024-53269
#    Code-related: True
#
# 64. CVE-2024-56128
#    Code-related: True
#
# 65. CVE-2024-51479
#    Code-related: True
#
# 66. CVE-2024-54677
#    Code-related: True
#
# 67. CVE-2024-50379
#    Code-related: True
#
# 68. CVE-2024-55949
#    Code-related: True
#
# 69. CVE-2024-55887
#    Code-related: True
#
# 70. CVE-2024-53677
#    Code-related: True
#
# 71. CVE-2024-12397
#    Code-related: True
#
# 72. CVE-2024-55601
#    Code-related: True
#
# 73. CVE-2024-55565
#    Code-related: True
#
# 74. CVE-2024-12369
#    Code-related: True
#
# 75. CVE-2024-12254
#    Code-related: True
#
# 76. CVE-2022-41137
#    Code-related: True
#
# 77. CVE-2024-38829
#    Code-related: True
#
# 78. CVE-2024-53908
#    Code-related: True
#
# 79. CVE-2024-53907
#    Code-related: True
#
# 80. CVE-2024-53990
#    Code-related: True
#
# 81. CVE-2024-53259
#    Code-related: True
#
# 82. CVE-2024-53981
#    Code-related: True
#
# 83. CVE-2024-38827
#    Code-related: True
#
# 84. CVE-2024-53861
#    Code-related: True
#
# 85. CVE-2024-53848
#    Code-related: True
#
# 86. CVE-2024-36623
#    Code-related: True
#
# 87. CVE-2024-36621
#    Code-related: True
#
# 88. CVE-2024-36620
#    Code-related: True
#
# 89. CVE-2024-8676
#    Code-related: True
#
# 90. CVE-2024-11694
#    Code-related: True
#
# 91. CVE-2023-2142
#    Code-related: True
