# %%
import requests

def fetch_cves(limit=10000):
    base_url = "https://access.redhat.com/labs/securitydataapi/cve.json"
    cves = []
    page = 1
    per_page = 100  # Number of CVEs per page (max allowed by the API)

    while len(cves) < limit:
        url = f"{base_url}?page={page}&per_page={per_page}"
        response = requests.get(url)
        
        if response.status_code != 200:
            print(f"Failed to fetch data: {response.status_code}")
            break
        
        data = response.json()
        if not data:
            break  # No more data available
        
        cves.extend(data)
        page += 1

        print(f"Fetched {len(cves)} CVEs so far...")

        if len(data) < per_page:
            break  # No more pages available

    return cves[:limit]

# Fetch the first 50,000 CVEs
cves = fetch_cves(limit=50000)

# Print the total number of CVEs fetched
print(f"Total CVEs fetched: {len(cves)}")
# Out:
# Fetched 100 CVEs so far...
# Fetched 200 CVEs so far...
# Fetched 300 CVEs so far...
# Fetched 400 CVEs so far...
# Fetched 500 CVEs so far...
# Fetched 600 CVEs so far...
# Fetched 700 CVEs so far...
# Fetched 800 CVEs so far...
# Fetched 900 CVEs so far...
# Fetched 1000 CVEs so far...
# Fetched 1100 CVEs so far...
# Fetched 1200 CVEs so far...
# Fetched 1300 CVEs so far...
# Fetched 1400 CVEs so far...
# Fetched 1500 CVEs so far...
# Fetched 1600 CVEs so far...
# Fetched 1700 CVEs so far...
# Fetched 1800 CVEs so far...
# Fetched 1900 CVEs so far...
# Fetched 2000 CVEs so far...
# Fetched 2100 CVEs so far...
# Fetched 2200 CVEs so far...
# Fetched 2300 CVEs so far...
# Fetched 2400 CVEs so far...
# Fetched 2500 CVEs so far...
# Fetched 2600 CVEs so far...
# Fetched 2700 CVEs so far...
# Fetched 2800 CVEs so far...
# Fetched 2900 CVEs so far...
# Fetched 3000 CVEs so far...
# Fetched 3100 CVEs so far...
# Fetched 3200 CVEs so far...
# Fetched 3300 CVEs so far...
# Fetched 3400 CVEs so far...
# Fetched 3500 CVEs so far...
# Fetched 3600 CVEs so far...
# Fetched 3700 CVEs so far...
# Fetched 3800 CVEs so far...
# Fetched 3900 CVEs so far...
# Fetched 4000 CVEs so far...
# Fetched 4100 CVEs so far...
# Fetched 4200 CVEs so far...
# Fetched 4300 CVEs so far...
# Fetched 4400 CVEs so far...
# Fetched 4500 CVEs so far...
# Fetched 4600 CVEs so far...
# Fetched 4700 CVEs so far...
# Fetched 4800 CVEs so far...
# Fetched 4900 CVEs so far...
# Fetched 5000 CVEs so far...
# Fetched 5100 CVEs so far...
# Fetched 5200 CVEs so far...
# Fetched 5300 CVEs so far...
# Fetched 5400 CVEs so far...
# Fetched 5500 CVEs so far...
# Fetched 5600 CVEs so far...
# Fetched 5700 CVEs so far...
# Fetched 5800 CVEs so far...
# Fetched 5900 CVEs so far...
# Fetched 6000 CVEs so far...
# Fetched 6100 CVEs so far...
# Fetched 6200 CVEs so far...
# Fetched 6300 CVEs so far...
# Fetched 6400 CVEs so far...
# Fetched 6500 CVEs so far...
# Fetched 6600 CVEs so far...
# Fetched 6700 CVEs so far...
# Fetched 6800 CVEs so far...
# Fetched 6900 CVEs so far...
# Fetched 7000 CVEs so far...
# Fetched 7100 CVEs so far...
# Fetched 7200 CVEs so far...
# Fetched 7300 CVEs so far...
# Fetched 7400 CVEs so far...
# Fetched 7500 CVEs so far...
# Fetched 7600 CVEs so far...
# Fetched 7700 CVEs so far...
# Fetched 7800 CVEs so far...
# Fetched 7900 CVEs so far...
# Fetched 8000 CVEs so far...
# Fetched 8100 CVEs so far...
# Fetched 8200 CVEs so far...
# Fetched 8300 CVEs so far...
# Fetched 8400 CVEs so far...
# Fetched 8500 CVEs so far...
# Fetched 8600 CVEs so far...
# Fetched 8700 CVEs so far...
# Fetched 8800 CVEs so far...
# Fetched 8900 CVEs so far...
# Fetched 9000 CVEs so far...
# Fetched 9100 CVEs so far...
# Fetched 9200 CVEs so far...
# Fetched 9300 CVEs so far...
# Fetched 9400 CVEs so far...
# Fetched 9500 CVEs so far...
# Fetched 9600 CVEs so far...
# Fetched 9700 CVEs so far...
# Fetched 9800 CVEs so far...
# Fetched 9900 CVEs so far...
# Fetched 10000 CVEs so far...
# Fetched 10100 CVEs so far...
# Fetched 10200 CVEs so far...
# Fetched 10300 CVEs so far...
# Fetched 10400 CVEs so far...
# Fetched 10500 CVEs so far...
# Fetched 10600 CVEs so far...
# Fetched 10700 CVEs so far...
# Fetched 10800 CVEs so far...
# Fetched 10900 CVEs so far...
# Fetched 11000 CVEs so far...
# Fetched 11100 CVEs so far...
# Fetched 11200 CVEs so far...
# Fetched 11300 CVEs so far...
# Fetched 11400 CVEs so far...
# Fetched 11500 CVEs so far...
# Fetched 11600 CVEs so far...
# Fetched 11700 CVEs so far...
# Fetched 11800 CVEs so far...
# Fetched 11900 CVEs so far...
# Fetched 12000 CVEs so far...
# Fetched 12100 CVEs so far...
# Fetched 12200 CVEs so far...
# Fetched 12300 CVEs so far...
# Fetched 12400 CVEs so far...
# Fetched 12500 CVEs so far...
# Fetched 12600 CVEs so far...
# Fetched 12700 CVEs so far...
# Fetched 12800 CVEs so far...
# Fetched 12900 CVEs so far...
# Fetched 13000 CVEs so far...
# Fetched 13100 CVEs so far...
# Fetched 13200 CVEs so far...
# Fetched 13300 CVEs so far...
# Fetched 13400 CVEs so far...
# Fetched 13500 CVEs so far...
# Fetched 13600 CVEs so far...
# Fetched 13700 CVEs so far...
# Fetched 13800 CVEs so far...
# Fetched 13900 CVEs so far...
# Fetched 14000 CVEs so far...
# Fetched 14100 CVEs so far...
# Fetched 14200 CVEs so far...
# Fetched 14300 CVEs so far...
# Fetched 14400 CVEs so far...
# Fetched 14500 CVEs so far...
# Fetched 14600 CVEs so far...
# Fetched 14700 CVEs so far...
# Fetched 14800 CVEs so far...
# Fetched 14900 CVEs so far...
# Fetched 15000 CVEs so far...
# Fetched 15100 CVEs so far...
# Fetched 15200 CVEs so far...
# Fetched 15300 CVEs so far...
# Fetched 15400 CVEs so far...
# Fetched 15500 CVEs so far...
# Fetched 15600 CVEs so far...
# Fetched 15700 CVEs so far...
# Fetched 15800 CVEs so far...
# Fetched 15900 CVEs so far...
# Fetched 16000 CVEs so far...
# Fetched 16100 CVEs so far...
# Fetched 16200 CVEs so far...
# Fetched 16300 CVEs so far...
# Fetched 16400 CVEs so far...
# Fetched 16500 CVEs so far...
# Fetched 16600 CVEs so far...
# Fetched 16700 CVEs so far...
# Fetched 16800 CVEs so far...
# Fetched 16900 CVEs so far...
# Fetched 17000 CVEs so far...
# Fetched 17100 CVEs so far...
# Fetched 17200 CVEs so far...
# Fetched 17300 CVEs so far...
# Fetched 17400 CVEs so far...
# Fetched 17500 CVEs so far...
# Fetched 17600 CVEs so far...
# Fetched 17700 CVEs so far...
# Fetched 17800 CVEs so far...
# Fetched 17900 CVEs so far...
# Fetched 18000 CVEs so far...
# Fetched 18100 CVEs so far...
# Fetched 18200 CVEs so far...
# Fetched 18300 CVEs so far...
# Fetched 18400 CVEs so far...
# Fetched 18500 CVEs so far...
# Fetched 18600 CVEs so far...
# Fetched 18700 CVEs so far...
# Fetched 18800 CVEs so far...
# Fetched 18900 CVEs so far...
# Fetched 19000 CVEs so far...
# Fetched 19100 CVEs so far...
# Fetched 19200 CVEs so far...
# Fetched 19300 CVEs so far...
# Fetched 19400 CVEs so far...
# Fetched 19500 CVEs so far...
# Fetched 19600 CVEs so far...
# Fetched 19700 CVEs so far...
# Fetched 19800 CVEs so far...
# Fetched 19900 CVEs so far...
# Fetched 20000 CVEs so far...
# Fetched 20100 CVEs so far...
# Fetched 20200 CVEs so far...
# Fetched 20300 CVEs so far...
# Fetched 20400 CVEs so far...
# Fetched 20500 CVEs so far...
# Fetched 20600 CVEs so far...
# Fetched 20700 CVEs so far...
# Fetched 20800 CVEs so far...
# Fetched 20900 CVEs so far...
# Fetched 21000 CVEs so far...
# Fetched 21100 CVEs so far...
# Fetched 21200 CVEs so far...
# Fetched 21300 CVEs so far...
# Fetched 21400 CVEs so far...
# Fetched 21500 CVEs so far...
# Fetched 21600 CVEs so far...
# Fetched 21700 CVEs so far...
# Fetched 21800 CVEs so far...
# Fetched 21900 CVEs so far...
# Fetched 22000 CVEs so far...
# Fetched 22100 CVEs so far...
# Fetched 22200 CVEs so far...
# Fetched 22300 CVEs so far...
# Fetched 22400 CVEs so far...
# Fetched 22500 CVEs so far...
# Fetched 22600 CVEs so far...
# Fetched 22700 CVEs so far...
# Fetched 22800 CVEs so far...
# Fetched 22900 CVEs so far...
# Fetched 23000 CVEs so far...
# Fetched 23100 CVEs so far...
# Fetched 23200 CVEs so far...
# Fetched 23300 CVEs so far...
# Fetched 23400 CVEs so far...
# Fetched 23500 CVEs so far...
# Fetched 23600 CVEs so far...
# Fetched 23700 CVEs so far...
# Fetched 23800 CVEs so far...
# Fetched 23900 CVEs so far...
# Fetched 24000 CVEs so far...
# Fetched 24100 CVEs so far...
# Fetched 24200 CVEs so far...
# Fetched 24300 CVEs so far...
# Fetched 24400 CVEs so far...
# Fetched 24500 CVEs so far...
# Fetched 24600 CVEs so far...
# Fetched 24700 CVEs so far...
# Fetched 24800 CVEs so far...
# Fetched 24900 CVEs so far...
# Fetched 25000 CVEs so far...
# Fetched 25100 CVEs so far...
# Fetched 25200 CVEs so far...
# Fetched 25300 CVEs so far...
# Fetched 25400 CVEs so far...
# Fetched 25500 CVEs so far...
# Fetched 25600 CVEs so far...
# Fetched 25700 CVEs so far...
# Fetched 25800 CVEs so far...
# Fetched 25900 CVEs so far...
# Fetched 26000 CVEs so far...
# Fetched 26100 CVEs so far...
# Fetched 26200 CVEs so far...
# Fetched 26300 CVEs so far...
# Fetched 26400 CVEs so far...
# Fetched 26500 CVEs so far...
# Fetched 26600 CVEs so far...
# Fetched 26700 CVEs so far...
# Fetched 26800 CVEs so far...
# Fetched 26900 CVEs so far...
# Fetched 27000 CVEs so far...
# Fetched 27100 CVEs so far...
# Fetched 27200 CVEs so far...
# Fetched 27300 CVEs so far...
# Fetched 27400 CVEs so far...
# Fetched 27500 CVEs so far...
# Fetched 27600 CVEs so far...
# Fetched 27700 CVEs so far...
# Fetched 27800 CVEs so far...
# Fetched 27900 CVEs so far...
# Fetched 28000 CVEs so far...
# Fetched 28100 CVEs so far...
# Fetched 28200 CVEs so far...
# Fetched 28300 CVEs so far...
# Fetched 28400 CVEs so far...
# Fetched 28500 CVEs so far...
# Fetched 28600 CVEs so far...
# Fetched 28700 CVEs so far...
# Fetched 28800 CVEs so far...
# Fetched 28900 CVEs so far...
# Fetched 29000 CVEs so far...
# Fetched 29100 CVEs so far...
# Fetched 29200 CVEs so far...
# Fetched 29300 CVEs so far...
# Fetched 29400 CVEs so far...
# Fetched 29500 CVEs so far...
# Fetched 29600 CVEs so far...
# Fetched 29700 CVEs so far...
# Fetched 29800 CVEs so far...
# Fetched 29900 CVEs so far...
# Fetched 30000 CVEs so far...
# Fetched 30100 CVEs so far...
# Fetched 30200 CVEs so far...
# Fetched 30300 CVEs so far...
# Fetched 30400 CVEs so far...
# Fetched 30500 CVEs so far...
# Fetched 30600 CVEs so far...
# Fetched 30700 CVEs so far...
# Fetched 30800 CVEs so far...
# Fetched 30900 CVEs so far...
# Fetched 31000 CVEs so far...
# Fetched 31100 CVEs so far...
# Fetched 31200 CVEs so far...
# Fetched 31300 CVEs so far...
# Fetched 31400 CVEs so far...
# Fetched 31500 CVEs so far...
# Fetched 31600 CVEs so far...
# Fetched 31700 CVEs so far...
# Fetched 31800 CVEs so far...
# Fetched 31900 CVEs so far...
# Fetched 32000 CVEs so far...
# Fetched 32100 CVEs so far...
# Fetched 32200 CVEs so far...
# Fetched 32300 CVEs so far...
# Fetched 32400 CVEs so far...
# Fetched 32500 CVEs so far...
# Fetched 32600 CVEs so far...
# Fetched 32700 CVEs so far...
# Fetched 32800 CVEs so far...
# Fetched 32900 CVEs so far...
# Fetched 33000 CVEs so far...
# Fetched 33100 CVEs so far...
# Fetched 33200 CVEs so far...
# Fetched 33300 CVEs so far...
# Fetched 33400 CVEs so far...
# Fetched 33500 CVEs so far...
# Fetched 33600 CVEs so far...
# Fetched 33700 CVEs so far...
# Fetched 33800 CVEs so far...
# Fetched 33900 CVEs so far...
# Fetched 34000 CVEs so far...
# Fetched 34100 CVEs so far...
# Fetched 34200 CVEs so far...
# Fetched 34300 CVEs so far...
# Fetched 34400 CVEs so far...
# Fetched 34500 CVEs so far...
# Fetched 34600 CVEs so far...
# Fetched 34700 CVEs so far...
# Fetched 34800 CVEs so far...
# Fetched 34900 CVEs so far...
# Fetched 35000 CVEs so far...
# Fetched 35100 CVEs so far...
# Fetched 35200 CVEs so far...
# Fetched 35300 CVEs so far...
# Fetched 35400 CVEs so far...
# Fetched 35500 CVEs so far...
# Fetched 35600 CVEs so far...
# Fetched 35700 CVEs so far...
# Fetched 35800 CVEs so far...
# Fetched 35900 CVEs so far...
# Fetched 36000 CVEs so far...
# Fetched 36100 CVEs so far...
# Fetched 36200 CVEs so far...
# Fetched 36300 CVEs so far...
# Fetched 36400 CVEs so far...
# Fetched 36500 CVEs so far...
# Fetched 36600 CVEs so far...
# Fetched 36700 CVEs so far...
# Fetched 36800 CVEs so far...
# Fetched 36900 CVEs so far...
# Fetched 36971 CVEs so far...
# Total CVEs fetched: 36971

# %%
len(cves)
# Out:
# 36971

# %%
def extract_year_from_cve(cve_id):
    """
    Extracts the year from a CVE identifier.

    :param cve_id: A string representing the CVE ID (e.g., "CVE-2022-49043").
    :return: The year as an integer (e.g., 2022).
    """
    # Split the CVE ID by '-' and get the second part (the year)
    try:
        year = int(cve_id.split('-')[1])
        return year
    except (IndexError, ValueError) as e:
        print(f"Error extracting year from CVE ID: {e}")
        return None

# %%
final_packages = []
final_cves = []
fixed_states = []

# %%
def extract_from_openshift4_onwards(input_string):
    """
    Extracts all the data from 'openshift4/' onwards in the input string.

    :param input_string: The input string (e.g., "red_hat_openshift_container_platform_4:openshift4/oc-mirror-plugin-rhel8").
    :return: The substring starting from 'openshift4/' onwards. Returns None if 'openshift4/' is not found.
    """
    # Find the index of 'openshift4/'
    index = input_string.find('openshift4/')
    
    # If 'openshift4/' is found, extract the substring from that point onwards
    if index != -1:
        return input_string[index:]
    else:
        return None

# %%
def fetch_known_affected(vulnerabilities):
    known_affected_products = []
    for vulnerability in vulnerabilities:
        if "product_status" in vulnerability and "known_affected" in vulnerability["product_status"]:
            known_affected_products.extend(vulnerability["product_status"]["known_affected"])
    return known_affected_products

# %%
for cve in cves:
    cve_id = cve['CVE'].lower()
    year = extract_year_from_cve(cve_id)
    resource_url = f"https://security.access.redhat.com/data/csaf/v2/vex/{year}/{cve_id}.json"
    response = requests.get(resource_url)
    if response.status_code != 200:
        continue
    data = response.json()
    vulnerabilities = data.get("vulnerabilities", [])
    known_affected_products = fetch_known_affected(vulnerabilities)
    for known_affected_product in known_affected_products:
        if "openshift4/" in known_affected_product:
            curated_package = extract_from_openshift4_onwards(known_affected_product)
            final_packages.append(curated_package)
            final_cves.append(cve['CVE'])
            fixed_states.append("known_affected")

# %%
len(final_cves), len(final_packages)
# Out:
# (2155, 2155)

# %%
from pandas import DataFrame
df = DataFrame({'CVE': final_cves, 'package': final_packages, 'Fix State': fixed_states})
df.to_excel('known_affected.xlsx', sheet_name='sheet1', index=False)
